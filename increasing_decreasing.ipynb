# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelcasaril/python/blob/main/increasing_decreasing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercicio 07

# %%
v1 = int(input("Digite o numero 1"))
v2 = int(input("Digite o numero 2"))
v3 = int(input("Digite o numero 3"))

if v1>v2 and v1>v3:
    maior = v1
    if v2>v3:
        medio = v2
        menor = v3
    else:
        medio = v3
        menor = v2
            
elif v2>v1 and v2>v3:
    maior = v2
    if v3>v1:
        medio = v3
        menor = v1
    else:
        medio = v1
        menor = v3

else:
    maior = v3
    if v2>v1:
        medio = v2
        menor = v1
    else:
        medio = v1
        menor = v2

print(maior, medio, menor)
#print(menor, medio, maior)
# Out:
# Digite o numero 1188
# Digite o numero 25
# Digite o numero 318
# 188 18 5
