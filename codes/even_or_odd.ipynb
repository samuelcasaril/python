# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelcasaril/basic_python/blob/main/codes/even_or_odd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

num = int(input("Digite um numero para ver se eh par ou impar"))
resto = num%2

if resto==0:
    print("O numero eh par")
else:
    print("O numero eh impar")
# Out:
# Digite um numero para ver se eh par ou impar8
# O numero eh par
